# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshaj-sys/Akshaj-sys/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Google Colab !")
result = 10+20
print("The sum of 10 and 20 is:", result)
# Out:
# Hello, Google Colab !
# The sum of 10 and 20 is: 30
